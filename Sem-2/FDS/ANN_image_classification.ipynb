# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Define constants
IMG_HEIGHT = 150
IMG_WIDTH = 150
batch_size = 32
epochs = 10

# %%
# Data preprocessing
train_data_gen = ImageDataGenerator(rescale=1./255)
train_generator = train_data_gen.flow_from_directory(
    directory='/content/drive/MyDrive/dog_cat/train',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 557 images belonging to 2 classes.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Build the model
model = Sequential([
    Flatten(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs
)
# Out:
# Epoch 1/10
# 17/17 [==============================] - 9s 485ms/step - loss: 20.0851 - accuracy: 0.5105
# Epoch 2/10
# 17/17 [==============================] - 7s 424ms/step - loss: 4.7408 - accuracy: 0.5162
# Epoch 3/10
# 17/17 [==============================] - 8s 459ms/step - loss: 0.7969 - accuracy: 0.5371
# Epoch 4/10
# 17/17 [==============================] - 8s 456ms/step - loss: 0.6849 - accuracy: 0.5048
# Epoch 5/10
# 17/17 [==============================] - 7s 406ms/step - loss: 0.7202 - accuracy: 0.5018
# Epoch 6/10
# 17/17 [==============================] - 8s 470ms/step - loss: 0.6894 - accuracy: 0.5010
# Epoch 7/10
# 17/17 [==============================] - 7s 398ms/step - loss: 0.6873 - accuracy: 0.5162
# Epoch 8/10
# 17/17 [==============================] - 8s 468ms/step - loss: 0.7924 - accuracy: 0.5162
# Epoch 9/10
# 17/17 [==============================] - 8s 468ms/step - loss: 0.6909 - accuracy: 0.4990
# Epoch 10/10
# 17/17 [==============================] - 8s 456ms/step - loss: 0.6898 - accuracy: 0.4971

# %%
# Evaluate the model
test_data_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_data_gen.flow_from_directory(
    directory='/content/drive/MyDrive/dog_cat/test',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 140 images belonging to 2 classes.

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(test_generator)
print("Test Accuracy:", accuracy)
# Out:
# 5/5 [==============================] - 2s 374ms/step - loss: 0.6929 - accuracy: 0.5000
# Test Accuracy: 0.5
