# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"H:\DataScience-Lab\Sem-2\Time series analysis & forecasting\files\Total_weekly_air_passenger.csv")
df
# Out:
#      Unnamed: 0    X  First.Class  Business.Class  Economy.Class
# 0           108  108        1.636           1.524         19.260
# 1           109  109        1.741           2.212         18.781
# 2           110  110        1.597           1.777         17.445
# 3           111  111        1.943           2.552         19.628
# 4           112  112        1.660           1.889         17.692
# ..          ...  ...          ...             ...            ...
# 171         279  279        1.458           3.053         28.837
# 172         280  280        1.398           2.745         26.548
# 173         281  281        1.423           3.156         27.279
# 174         282  282        1.358           3.069         27.306
# 175         283  283        1.488           3.379         28.299
#
# [176 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0    X  First.Class  Business.Class  Economy.Class
# 0         108  108        1.636           1.524         19.260
# 1         109  109        1.741           2.212         18.781
# 2         110  110        1.597           1.777         17.445
# 3         111  111        1.943           2.552         19.628
# 4         112  112        1.660           1.889         17.692

# %%
df.tail()
# Out:
#      Unnamed: 0    X  First.Class  Business.Class  Economy.Class
# 171         279  279        1.458           3.053         28.837
# 172         280  280        1.398           2.745         26.548
# 173         281  281        1.423           3.156         27.279
# 174         282  282        1.358           3.069         27.306
# 175         283  283        1.488           3.379         28.299

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Unnamed: 0']
  ys = series['First.Class']
  
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Unnamed: 0', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Unnamed: 0')
_ = plt.ylabel('First.Class')

# %%
# Plotting the data for Economy.Class
plt.plot(df['X'], df['Economy.Class'], marker='o', linestyle='-', color='b')
plt.title('Weekly Air Passenger - Economy Class')
plt.xlabel('Week Number')
plt.ylabel('Passenger Count (Economy Class)')
plt.grid(True)
plt.show()

# %%
df1 = pd.read_csv(r"H:\DataScience-Lab\Sem-2\Time series analysis & forecasting\files\Monthly_anti-diabetic.csv")
df1
# Out:
#      Unnamed: 0    X         time      value
# 0             1    1  1991.500000   3.526591
# 1             2    2  1991.583333   3.180891
# 2             3    3  1991.666667   3.252221
# 3             4    4  1991.750000   3.611003
# 4             5    5  1991.833333   3.565869
# ..          ...  ...          ...        ...
# 199         200  200  2008.083333  21.654285
# 200         201  201  2008.166667  18.264945
# 201         202  202  2008.250000  23.107677
# 202         203  203  2008.333333  22.912510
# 203         204  204  2008.416667  19.431740
#
# [204 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0    X  First.Class  Business.Class  Economy.Class
# 0         108  108        1.636           1.524         19.260
# 1         109  109        1.741           2.212         18.781
# 2         110  110        1.597           1.777         17.445
# 3         111  111        1.943           2.552         19.628
# 4         112  112        1.660           1.889         17.692

# %%
df1= pd.read_csv(r"H:\DataScience-Lab\Sem-2\Time series analysis & forecasting\files\Monthly_anti-diabetic.csv",sep=',',parse_dates=['time'])
df1
# Out:
# C:\Users\devje\AppData\Local\Temp\ipykernel_10484\3067270268.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1= pd.read_csv(r"H:\DataScience-Lab\Sem-2\Time series analysis & forecasting\files\Monthly_anti-diabetic.csv",sep=',',parse_dates=['time'])
#      Unnamed: 0    X       time      value
# 0             1    1 1991-05-01   3.526591
# 1             2    2 1991-01-01   3.180891
# 2             3    3 1991-01-01   3.252221
# 3             4    4 1991-01-01   3.611003
# 4             5    5 1991-01-01   3.565869
# ..          ...  ...        ...        ...
# 199         200  200 2008-01-01  21.654285
# 200         201  201 2008-01-01  18.264945
# 201         202  202 2008-01-01  23.107677
# 202         203  203 2008-01-01  22.912510
# 203         204  204 2008-01-01  19.431740
#
# [204 rows x 4 columns]

# %%
import seaborn as sns

def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['X']
  ys = series['value']
  
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df1.sort_values('X', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('X')
_ = plt.ylabel('value')

# %% [markdown]
# New 18-1-24

# %%
df['Economy_Class_SMA'] = df['Economy.Class'].rolling(10).mean()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Economy.Class'], label='Economy Class')
plt.plot(df['Economy_Class_SMA'])
plt.title('Economy Class Simple Moving Average')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
df['Economy_Class_SMA_5'] = df['Economy.Class'].rolling(5).mean()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Economy.Class'], label='Economy Class')
plt.plot(df['Economy_Class_SMA_5'])
plt.title('Economy Class Simple Moving Average')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
df['Economy_Class_SMA_15'] = df['Economy.Class'].rolling(15).mean()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Economy.Class'], label='Economy Class')
plt.plot(df['Economy_Class_SMA_15'])
plt.title('Economy Class Simple Moving Average')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Economy.Class'], label='Economy Class')
plt.plot(df['Economy_Class_SMA_5'])
plt.plot(df['Economy_Class_SMA_15'])
plt.title('Economy Class Simple Moving Average')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
import pandas as pd

# Assuming df is your DataFrame, and 'Economy.Class' is the column for which you want to calculate CMA
window_size = 3  # Adjust the window size as needed

# Calculate Central Moving Average
df['Economy_Class_CMA'] = df['Economy.Class'].rolling(window=window_size, center=True).mean()

# Plotting the original data and CMA
plt.figure(figsize=(10, 6))
plt.plot(df['Economy.Class'], label='Economy Class', color='#3498db', linewidth=2)
plt.plot(df['Economy_Class_CMA'], label=f'CMA {window_size}', linestyle='--', color='#e74c3c', linewidth=2)

# Adding labels and title
plt.title('Economy Class Central Moving Average', fontsize=16)
plt.xlabel('Index', fontsize=12)
plt.ylabel('Value', fontsize=12)

# Adding legend with a better location
plt.legend(loc='upper left')

# Adding grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Adding a light gray background color for better contrast
plt.gca().set_facecolor('#ecf0f1')

# Show the plot
plt.show()

# %%
import pandas as pd

# Assuming df is your DataFrame, and 'Economy.Class' is the column for which you want to calculate weighted CMA
window_size = 3  # Adjust the window size as needed
weights = [0.25, 0.5, 0.25]  # Adjust the weights according to your requirements

# Define a custom weighted average function
def weighted_average(x):
    return (x * weights).sum()

# Calculate Weighted Central Moving Average
df['Economy_Class_Weighted_CMA'] = df['Economy.Class'].rolling(window=window_size, center=True).apply(weighted_average, raw=True)

# Plotting the original data and Weighted CMA
plt.figure(figsize=(10, 6))
plt.plot(df['Economy.Class'], label='Economy Class', color='#3498db', linewidth=2)
plt.plot(df['Economy_Class_Weighted_CMA'], label=f'Weighted CMA', linestyle='--', color='#e74c3c', linewidth=2)

# Adding labels and title
plt.title('Economy Class Weighted Central Moving Average', fontsize=16)
plt.xlabel('Index', fontsize=12)
plt.ylabel('Value', fontsize=12)

# Adding legend with a better location
plt.legend(loc='upper left')

# Adding grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Adding a light gray background color for better contrast
plt.gca().set_facecolor('#ecf0f1')

# Show the plot
plt.show()
