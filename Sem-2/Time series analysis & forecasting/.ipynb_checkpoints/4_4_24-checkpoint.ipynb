# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"H:\DataScience-Lab\Sem-2\Time series analysis & forecasting\files\data.csv")
df
# Out:
#      Southern  Osc_Year&Month  Year  Month
# 0        -0.7         1955.04  1955      1
# 1         1.3         1955.13  1955      2
# 2         0.1         1955.21  1955      3
# 3        -0.9         1955.29  1955      4
# 4         0.8         1955.38  1955      5
# ..        ...             ...   ...    ...
# 451       0.0         1992.63  1992      8
# 452       0.0         1992.71  1992      9
# 453      -1.9         1992.79  1992     10
# 454      -0.9         1992.88  1992     11
# 455      -1.1         1992.96  1992     12
#
# [456 rows x 4 columns]

# %%
df1 = pd.read_csv(r"H:\DataScience-Lab\Sem-2\Time series analysis & forecasting\files\MAVRODAT.csv")
df1.head()
# Out:
#    Transmittance
# 0         2.0018
# 1         2.0017
# 2         2.0018
# 3         2.0019
# 4         2.0018

# %%
df2 = pd.read_csv(r"H:\DataScience-Lab\Sem-2\Time series analysis & forecasting\files\FLICKERDAT.csv")
df2.head()
# Out:
#           Y
# 0 -0.000282
# 1 -0.001071
# 2  0.001569
# 3 -0.000156
# 4  0.003643

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
# Plot the autocorrelation function
plot_acf(df['Southern'], lags=100)  # Adjust lags as needed
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Function of Southern Oscillation Data')
plt.show()

# %%
# Create the autocorrelation plot
plt.figure(figsize=(10, 6))
pd.plotting.autocorrelation_plot(df2)
plt.title('Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.show()

# %%
# Plot Partial Autocorrelation
plot_pacf(df['Southern'], alpha=0.05, use_vlines=True)
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.title('Partial Autocorrelation Plot')
plt.show()

# %%
def autocorr(x):
    n = len(x)
    mean = np.mean(x)
    corr = np.correlate(x - mean, x - mean, mode='full')
    corr /= np.max(corr)
    return corr[n - 1:]


# Compute the autocorrelation function
corr = autocorr(df2["Y"])

# Plot the autocorrelation function
plt.plot(corr)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %%
def autocorr(x):
    n = len(x)
    mean = np.mean(x)
    corr = np.correlate(x - mean, x - mean, mode='full')
    corr /= np.max(corr)
    return corr[n - 1:]


# Compute the autocorrelation function
corr = autocorr(df["Southern"])

# Plot the autocorrelation function
plt.plot(corr)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df1.index,df1['Transmittance'])
plt.title('Run-Sequence Plot of Southern Oscillation Index')
plt.xlabel('Time')
plt.ylabel('Southern Oscillation Index')
plt.show()

# %%
plt.figure(figsize=(10, 6))
pd.plotting.autocorrelation_plot(df2['Y'])
plt.title('Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.show()
