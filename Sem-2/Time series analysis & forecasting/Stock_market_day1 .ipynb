# %%
import pandas as pd

# %%
df = pd.read_csv(r"H:\DataScience-Lab\Sem-2\Time series analysis & forecasting\files\ADANIPOWER_NS.csv")
df
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 0    2023-01-04  294.750000  296.000000  284.549988  286.600006  286.600006  \
# 1    2023-01-05  287.950012  293.200012  277.000000  288.750000  288.750000
# 2    2023-01-06  290.700012  291.000000  281.100006  283.399994  283.399994
# 3    2023-01-09  286.950012  294.000000  285.200012  287.700012  287.700012
# 4    2023-01-10  287.950012  287.950012  274.649994  279.200012  279.200012
# ..          ...         ...         ...         ...         ...         ...
# 242  2023-12-29  520.500000  527.000000  518.000000  525.150024  525.150024
# 243  2024-01-01  525.150024  533.950012  519.099976  523.250000  523.250000
# 244  2024-01-02  525.000000  525.000000  515.000000  518.599976  518.599976
# 245  2024-01-03  538.000000  544.500000  525.000000  544.500000  544.500000
# 246  2024-01-04  548.000000  561.450012  537.299988  558.549988  558.549988
#
#       Volume
# 0    1643562
# 1    1868579
# ...

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close
# 0  2023-01-04  294.750000  296.000000  284.549988  286.600006  286.600006  \
# 1  2023-01-05  287.950012  293.200012  277.000000  288.750000  288.750000
# 2  2023-01-06  290.700012  291.000000  281.100006  283.399994  283.399994
# 3  2023-01-09  286.950012  294.000000  285.200012  287.700012  287.700012
# 4  2023-01-10  287.950012  287.950012  274.649994  279.200012  279.200012
#
#     Volume
# 0  1643562
# 1  1868579
# 2  2199728
# 3  1770223
# 4  2577634

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# Plotting the closing prices
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], marker='o', linestyle='-')
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
# Calculate the rolling average of the 'Open' column for the first 30 rows
df['Open_new'] = df['Open'].rolling(window=30, min_periods=1).mean()

# Shift the values down by 30 rows
df['Open_new'] = df['Open_new'].shift(30)

# Display the resulting DataFrame
df
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 0    2023-01-04  294.750000  296.000000  284.549988  286.600006  286.600006  \
# 1    2023-01-05  287.950012  293.200012  277.000000  288.750000  288.750000
# 2    2023-01-06  290.700012  291.000000  281.100006  283.399994  283.399994
# 3    2023-01-09  286.950012  294.000000  285.200012  287.700012  287.700012
# 4    2023-01-10  287.950012  287.950012  274.649994  279.200012  279.200012
# ..          ...         ...         ...         ...         ...         ...
# 242  2023-12-29  520.500000  527.000000  518.000000  525.150024  525.150024
# 243  2024-01-01  525.150024  533.950012  519.099976  523.250000  523.250000
# 244  2024-01-02  525.000000  525.000000  515.000000  518.599976  518.599976
# 245  2024-01-03  538.000000  544.500000  525.000000  544.500000  544.500000
# 246  2024-01-04  548.000000  561.450012  537.299988  558.549988  558.549988
#
#       Volume    Open_new
# 0    1643562         NaN
# ...

# %%
# # Plotting the 'Open' and 'Open_new' values over time
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Open'], label='Open', marker='o', linestyle='-', color='blue')
plt.plot(df['Date'], df['Open_new'], label='Open_new', marker='o', linestyle='-', color='green')
plt.title('Open and Open_new Values Over Time')
plt.xlabel('Date')
plt.ylabel('Open Value')
plt.legend()
plt.show()

# plt.plot(df.Date,df.Open)
# plt.plot(df.Date,df.Open_new)
# plt.show()

# %%
df['Low_new'] = df['Low'].rolling(30).mean()
df['High_new'] = df['High'].rolling(30).mean()
df['Close_new'] = df['Close'].rolling(30).mean()
df['Volume_new'] = df['Volume'].rolling(30).mean()

# %%
plt.plot(df.Date,df.Low)
plt.plot(df.Date,df.Low_new)
plt.show()

# %%
plt.plot(df.Date,df.High)
plt.plot(df.Date,df.High_new)
plt.show()

# %%
plt.plot(df.Date,df.Close)
plt.plot(df.Date,df.Close_new)
plt.show()

# %%
plt.plot(df.Date,df.Volume)
plt.plot(df.Date,df.Volume_new)
plt.show()

# %%
df['Open_Error']=df['Open']-df['Open_new']
df['Low_Error']=df['Low']-df['Low_new']
df['High_Error']=df['High']-df['High_new']
df['Close_Error']=df['Close']-df['Close_new']

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 0    2023-01-04  294.750000  296.000000  284.549988  286.600006  286.600006  \
# 1    2023-01-05  287.950012  293.200012  277.000000  288.750000  288.750000
# 2    2023-01-06  290.700012  291.000000  281.100006  283.399994  283.399994
# 3    2023-01-09  286.950012  294.000000  285.200012  287.700012  287.700012
# 4    2023-01-10  287.950012  287.950012  274.649994  279.200012  279.200012
# ..          ...         ...         ...         ...         ...         ...
# 242  2023-12-29  520.500000  527.000000  518.000000  525.150024  525.150024
# 243  2024-01-01  525.150024  533.950012  519.099976  523.250000  523.250000
# 244  2024-01-02  525.000000  525.000000  515.000000  518.599976  518.599976
# 245  2024-01-03  538.000000  544.500000  525.000000  544.500000  544.500000
# 246  2024-01-04  548.000000  561.450012  537.299988  558.549988  558.549988
#
# ...

# %%
df.isnull().mean()
# Out:
# Date           0.000000
# Open           0.000000
# High           0.000000
# Low            0.000000
# Close          0.000000
# Adj Close      0.000000
# Volume         0.000000
# Open_new       0.121457
# Low_new        0.117409
# High_new       0.117409
# Close_new      0.117409
# Volume_new     0.117409
# Error          0.121457
# Open_Error     0.121457
# Low_Error      0.117409
# High_Error     0.117409
# Close_Error    0.117409
# dtype: float64

# %%
df['open_new_20'] = df['Open'].rolling(20).mean()
df['open_new_40'] = df['Open'].rolling(40).mean()
df
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 0    2023-01-04  294.750000  296.000000  284.549988  286.600006  286.600006  \
# 1    2023-01-05  287.950012  293.200012  277.000000  288.750000  288.750000
# 2    2023-01-06  290.700012  291.000000  281.100006  283.399994  283.399994
# 3    2023-01-09  286.950012  294.000000  285.200012  287.700012  287.700012
# 4    2023-01-10  287.950012  287.950012  274.649994  279.200012  279.200012
# ..          ...         ...         ...         ...         ...         ...
# 242  2023-12-29  520.500000  527.000000  518.000000  525.150024  525.150024
# 243  2024-01-01  525.150024  533.950012  519.099976  523.250000  523.250000
# 244  2024-01-02  525.000000  525.000000  515.000000  518.599976  518.599976
# 245  2024-01-03  538.000000  544.500000  525.000000  544.500000  544.500000
# 246  2024-01-04  548.000000  561.450012  537.299988  558.549988  558.549988
#
# ...

# %%
plt.figure(figsize=(25,10))
plt.plot(df['Date'], df['Open'],color='blue')
plt.plot(df['Date'], df['Open_new'], color='red')
plt.plot(df['Date'], df['open_new_20'], color='black')
plt.plot(df['Date'], df['open_new_40'], color='green')
plt.show()

# %%
df['Open_20new'] = df['Open'].rolling(20).mean()
df['Low_20new'] = df['Low'].rolling(20).mean()
df['High_20new'] = df['High'].rolling(20).mean()
df['Close_20new'] = df['Close'].rolling(20).mean()
df['Volume_20new'] = df['Volume'].rolling(20).mean()

df['Open_40new'] = df['Open'].rolling(40).mean()
df['Low_40new'] = df['Low'].rolling(40).mean()
df['High_40new'] = df['High'].rolling(40).mean()
df['Close_40new'] = df['Close'].rolling(40).mean()
df['Volume_40new'] = df['Volume'].rolling(40).mean()

# %%
plt.plot(df.Date,df.Open)
plt.plot(df.Date,df.Open_new)
plt.plot(df.Date,df.Open_20new)
plt.plot(df.Date,df.Open_40new)
plt.show()

# %%
for i in range(20, 51):
    df['Open_new_'+str(i)] = df['Open'].rolling(i).mean()

# %%
# Find the total for each newly generated column
totals = df.filter(like='Open_new_').sum(axis=0)

# Display the totals
print(totals)
# Out:
# Open_new_20    65574.267630
# Open_new_21    65176.678696
# Open_new_22    64781.277393
# Open_new_23    64391.782725
# Open_new_24    64006.564695
# Open_new_25    63627.754108
# Open_new_26    63254.765489
# Open_new_27    62886.090842
# Open_new_28    62523.350098
# Open_new_29    62167.050094
# Open_new_30    61816.620091
# Open_new_31    61471.595250
# Open_new_32    61131.495398
# Open_new_33    60795.651598
# Open_new_34    60463.453022
# Open_new_35    60134.320079
# Open_new_36    59807.501465
# Open_new_37    59483.375749
# Open_new_38    59161.834281
# Open_new_39    58843.009042
# Open_new_40    58527.147564
# Open_new_41    58213.354940
# Open_new_42    57901.404820
# Open_new_43    57591.264009
# Open_new_44    57282.817099
# Open_new_45    56975.910051
# Open_new_46    56670.240266
# Open_new_47    56365.930898
# Open_new_48    56062.974003
# Open_new_49    55761.620451
# Open_new_50    55461.899041
# dtype: float64

# %%
error_df = pd.DataFrame()

# Create error columns and calculate errors
for i in range(20, 51):
    col_name = 'Open_new_' + str(i)
    df[col_name] = df['Open'].rolling(i).mean()
    
    error_col = df[col_name] - df['Open']
    error_df[col_name] = error_col

# Sum the absolute errors for each error column
total_errors = error_df.abs().sum()

# Find the error column with the lowest total error
min_error_column = total_errors.idxmin()

print("Column with the lowest total error:", min_error_column)
# Out:
# Column with the lowest total error: Open_new_20

# %%
for i in range(20, 51):
    df['Open_new_'+str(i)] = df['Open'].rolling(i).mean()

# %%
for i in range(20, 51):
    df['Open_error_'+str(i)] = df['Open']-df['Open_new_'+str(i)]

# %%
df.info
# Out:
# <bound method DataFrame.info of            Date        Open        High         Low       Close   Adj Close
# 0    2023-01-04  294.750000  296.000000  284.549988  286.600006  286.600006  \
# 1    2023-01-05  287.950012  293.200012  277.000000  288.750000  288.750000
# 2    2023-01-06  290.700012  291.000000  281.100006  283.399994  283.399994
# 3    2023-01-09  286.950012  294.000000  285.200012  287.700012  287.700012
# 4    2023-01-10  287.950012  287.950012  274.649994  279.200012  279.200012
# ..          ...         ...         ...         ...         ...         ...
# 242  2023-12-29  520.500000  527.000000  518.000000  525.150024  525.150024
# 243  2024-01-01  525.150024  533.950012  519.099976  523.250000  523.250000
# 244  2024-01-02  525.000000  525.000000  515.000000  518.599976  518.599976
# 245  2024-01-03  538.000000  544.500000  525.000000  544.500000  544.500000
# 246  2024-01-04  548.000000  561.450012  537.299988  558.549988  558.549988
#
# ...
