# %%
a = 5
a
# Out:
# 5

# %%
a.
# Out:
# 5

# %%
import re
str = "Sat, Mon, Hat, Mat" 
allstr = re.findall("[a-m]at", str)
print(allstr)
# Out:
# []

# %%
string = "example 123 split string"
result = re.findall(r'\b\w\w', string)
result
# Out:
# ['ex', '12', 'sp', 'st']

# %%
a1 = "abc@gmail.com, def@yahoo.in, abc@gmail.edu, cer@gmail.com"

#output = list(set(email.split('.')[-1] for email in a1.split(', ')))
# output = re.findall(r'\.\w+', a1)  case: 1
# case 2
output = re.findall(r'\@\w+.(\w+)', a1)


print(output)
# Out:
# ['com', 'in', 'edu', 'com']

# %%
paragraph = "This is the first sentence. This is the second sentence. And here is the third sentence."

sentence_pattern = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s',paragraph)
sentence_pattern
# Out:
# ['This is the first sentence.',
#  'This is the second sentence.',
#  'And here is the third sentence.']

# %%
paragraph = "This is the first sentence.This is the second sentence.Here is the third sentence. Mr. x is very happy."

# sentence_pattern = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s',paragraph)

sentence_pattern = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)',paragraph)
sentence_pattern
# Out:
# ['This is the first sentence.',
#  'This is the second sentence.',
#  'Here is the third sentence.',
#  ' Mr. x is very happy.',
#  '']

# %%
re.split(r'[.!?]',paragraph)
# Out:
# ['This is the first sentence',
#  'This is the second sentence',
#  'Here is the third sentence',
#  ' Mr',
#  ' x is very happy',
#  '']

# %%
paragraph1 = "This is the first sentence.This is the second sentence.Here is the third sentence.Mr. X is very happy."
re.split(r'[.!?]',paragraph1)
# Out:
# ['This is the first sentence',
#  'This is the second sentence',
#  'Here is the third sentence',
#  'Mr',
#  ' X is very happy',
#  '']

# %%
paragraph1 = "This is the first sentence. This is the second sentence. Here is the third sentence. Mr. X is very happy."

# Define a regular expression pattern to split sentences
sc1 = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s',paragraph1)
sc1
# Out:
# ['This is the first sentence.',
#  'This is the second sentence.',
#  'Here is the third sentence.',
#  'Mr. X is very happy.']

# %%
with open(r"H:\M.tech Data science PDPU\Sem-2\NLP\stopwords-en.txt", 'r',encoding='utf-8') as file:
        st = file.read()
        print(st)
# Out:
# 'll
# 'tis
# 'twas
# 've
# 10
# 39
# a
# a's
# able
# ableabout
# about
# above
# abroad
# abst
# accordance
# according
# accordingly
# across
# act
# actually
# ad
# added
# adj
# adopted
# ae
# af
# affected
# affecting
# affects
# after
# afterwards
# ag
# again
# against
# ago
# ah
# ahead
# ai
# ain't
# aint
# al
# all
# allow
# allows
# almost
# alone
# along
# alongside
# already
# also
# although
# always
# am
# amid
# amidst
# among
# amongst
# amoungst
# amount
# an
# and
# announce
# another
# any
# anybody
# anyhow
# anymore
# anyone
# anything
# anyway
# anyways
# anywhere
# ao
# apart
# apparently
# appear
# appreciate
# appropriate
# approximately
# aq
# ar
# are
# area
# areas
# aren
# aren't
# arent
# arise
# around
# arpa
# as
# aside
# ask
# asked
# asking
# asks
# associated
# at
# au
# auth
# available
# aw
# away
# awfully
# az
# b
# ba
# back
# backed
# backing
# backs
# backward
# backwards
# bb
# bd
# be
# became
# because
# become
# becomes
# becoming
# ...

# %%
# Sample paragraph
paragraph = """
Natural language processing (NLP) is a subfield of artificial intelligence (AI) that focuses on the interaction between computers and humans using natural language. It involves the development of algorithms and models to enable machines to understand, interpret, and generate human-like text. Stopwords are common words that are often removed during the preprocessing of text data to focus on the meaningful content. Examples of stopwords include 'the,' 'and,' 'is,' and 'in.' In NLP tasks, stopwords may be excluded to improve the efficiency of algorithms and highlight important information. Let's create a list of stopwords and then filter them out from the sample paragraph.
"""

# Split the content into a list of stopwords
stopwords_list = st.split('\n')

# Remove any empty strings or whitespaces from the list
stopwords_list = [stopword.strip() for stopword in stopwords_list if stopword.strip()]

# Split the paragraph into words
words_in_paragraph = paragraph.split()

# Create a list of non-stopwords
non_stopwords_list = [word for word in words_in_paragraph if word.lower() not in stopwords_list]

# Print the list of stopwords and non-stopwords
print("Stopwords:", stopwords_list)
print("\nNon-Stopwords:", non_stopwords_list)
# Out:
# Stopwords: ["'ll", "'tis", "'twas", "'ve", '10', '39', 'a', "a's", 'able', 'ableabout', 'about', 'above', 'abroad', 'abst', 'accordance', 'according', 'accordingly', 'across', 'act', 'actually', 'ad', 'added', 'adj', 'adopted', 'ae', 'af', 'affected', 'affecting', 'affects', 'after', 'afterwards', 'ag', 'again', 'against', 'ago', 'ah', 'ahead', 'ai', "ain't", 'aint', 'al', 'all', 'allow', 'allows', 'almost', 'alone', 'along', 'alongside', 'already', 'also', 'although', 'always', 'am', 'amid', 'amidst', 'among', 'amongst', 'amoungst', 'amount', 'an', 'and', 'announce', 'another', 'any', 'anybody', 'anyhow', 'anymore', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'ao', 'apart', 'apparently', 'appear', 'appreciate', 'appropriate', 'approximately', 'aq', 'ar', 'are', 'area', 'areas', 'aren', "aren't", 'arent', 'arise', 'around', 'arpa', 'as', 'aside', 'ask', 'asked', 'asking', 'asks', 'associated', 'at', 'au', 'auth', 'available', 'aw', 'away', 'awfully', 'az', 'b', 'ba', 'back
# ...
