# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("H:\DataScience-Lab\Foundation of DataScience\CSV\AirPassengers.csv")
df
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df["Month"]=pd.to_datetime(df["Month"])

# %%
df.head()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Month'], df['#Passengers'], marker='o', linestyle='-', color='g')

# Add labels and title
plt.xlabel('Month')
plt.ylabel('#Passengers')
plt.title('Monthly Passengers Over Time')

# Add notations for each data point
for i, row in df.iterrows():
    plt.text(row['Month'], row['#Passengers'], str(row['#Passengers']), ha='center', va='bottom')

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [raw]
# # Fit a linear regression line to the data
# coefficients = np.polyfit(df['Month'], df['#Passengers'], 1)
# trendline = np.poly1d(coefficients)
# plt.plot(df['Month'], trendline(df['Month']), linestyle='--', color='r', label='Trend Line')
#
# # Add labels and title
# plt.xlabel('Month')
# plt.ylabel('#Passengers')
# plt.title('Monthly Passengers Over Time')
#
# # Add notations for each data point
# for i, row in df.iterrows():
#     plt.text(row['Month'], row['#Passengers'], str(row['#Passengers']), ha='center', va='bottom')
#
# # Display the plot
# plt.grid(True)
# plt.tight_layout()
# plt.legend()
# plt.show()

# %%
# Plot the data points
plt.figure(figsize=(10, 6))
plt.scatter(df['Month'], df['#Passengers'], label='Data', color='g')

# Fit a linear regression line to the data
coefficients = np.polyfit(range(len(df)), df['#Passengers'], 1)
trendline = np.poly1d(coefficients)
plt.plot(df['Month'], trendline(range(len(df))))

# Add labels and title
plt.xlabel('Month')
plt.ylabel('#Passengers')
plt.title('Monthly Passengers Over Time')

# Add notations for each data point
for i, row in df.iterrows():
    plt.text(row['Month'], row['#Passengers'], str(row['#Passengers']), ha='center', va='bottom')
    
# Display the plot
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# %% [raw]
# # Plot the data points
# plt.figure(figsize=(10, 6))
# plt.scatter(df['Month'], df['#Passengers'], label='Data', color='blue')
#
# # Fit and plot the trend line
# coefficients = np.polyfit(range(len(df)), df['#Passengers'], 1)
# trend_line = np.poly1d(coefficients)
# plt.plot(df['Month'], trend_line(range(len(df))))
#
# # Add labels and legend
# plt.xlabel('Month')
# plt.ylabel('#Passengers')
# plt.title('Passenger Trend Over Time')
# plt.legend()
#
# # Show the plot
# plt.tight_layout()
# plt.show()
