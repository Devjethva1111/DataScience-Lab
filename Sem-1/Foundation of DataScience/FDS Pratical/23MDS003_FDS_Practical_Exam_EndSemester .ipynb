# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("H:\M.tech Data science PDPU\set2.csv")
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre
# 0       1    18-Apr-14                     2 States          LW    Romance  \
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget
# 0     1    18-Apr-14            2 States          LW    Romance      36  \
# 1     2     4-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama        7
# 4     5     4-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
df.tail()
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy  \
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649

# %% [markdown]
# 1. How many records are present in the dataset?Print the Metadata information of the dataset.

# %%
df.shape
# Out:
# (149, 10)

# %%
df.shape[0]
# Out:
# 149

# %%
df.shape[1]
# Out:
# 10

# %%
df.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews
# count  149.000000  149.000000           149.000000  1.490000e+02  \
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
df["month"]=pd.DatetimeIndex(df["Release Date"]).month

# %%
df["month"]
# Out:
# 0      4
# 1      1
# 2      7
# 3      1
# 4      7
#       ..
# 144    2
# 145    3
# 146    3
# 147    3
# 148    5
# Name: month, Length: 149, dtype: int32

# %% [markdown]
# 2. how many movies got released in each genre?which genre had highest number of releases?sort number of releases in each genre in descending order.

# %%
df["Genre"].value_counts()
# Out:
# Genre
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: count, dtype: int64

# %%
df["Genre"].sort_values(ascending=False)
# Out:
# 20     Thriller
# 1      Thriller
# 16     Thriller
# 30      Thriller
# 44      Thriller
#          ...
# 120       Drama
# 49        Drama
# 102       Drama
# 40        Drama
# 74        Drama
# Name: Genre, Length: 149, dtype: object

# %%
df["Genre"].value_counts().plot(kind="bar")
plt.xlabel("Genre")
plt.ylabel("Number of movies")
plt.title("Number of movies per genre")
plt.show()

# %% [markdown]
# Answer 3:-how many movies in each genre got released in different release times like long weekend,festive season,etc.

# %%
movies_count = df.groupby(['Genre', 'ReleaseTime']).size().reset_index(name='count')

# %%
movies_count
# Out:
#         Genre ReleaseTime  count
# 0      Drama           FS      4
# 1      Drama           HS      6
# 2      Drama           LW      1
# 3      Drama            N     24
# 4      Action          FS      3
# 5      Action          HS      3
# 6      Action          LW      3
# 7      Action           N     12
# 8     Action            N      3
# 9      Comedy          FS      3
# 10     Comedy          HS      5
# 11     Comedy          LW      5
# 12     Comedy           N     23
# 13    Romance          FS      3
# 14    Romance          HS      3
# 15    Romance          LW      4
# 16    Romance           N     15
# 17   Thriller          FS      4
# 18   Thriller          HS      1
# 19   Thriller          LW      1
# 20   Thriller           N     20
# 21  Thriller           LW      1
# 22  Thriller            N      2

# %% [markdown]
# Answer 4:- Which month of the year , maximum number of movie releases are seens?

# %%
df["month"]=pd.DatetimeIndex(df["Release Date"]).month

# %%
df["month"]
# Out:
# 0      4
# 1      1
# 2      7
# 3      1
# 4      7
#       ..
# 144    2
# 145    3
# 146    3
# 147    3
# 148    5
# Name: month, Length: 149, dtype: int32

# %%
print(df[["MovieName","month"]])
# Out:
#                        MovieName  month
# 0                       2 States      4
# 1                   Table No. 21      1
# 2             Amit Sahni Ki List      7
# 3               Rajdhani Express      1
# 4                   Bobby Jasoos      7
# ..                           ...    ...
# 144           Dum Laga Ke Haisha      2
# 145                         NH10      3
# 146  Dilliwali Zaalim Girlfriend      3
# 147                     Hunterrr      3
# 148                Kochadaiiyaan      5
#
# [149 rows x 2 columns]

# %% [markdown]
# Ans 5:- Which month of the year typically sees most releases of high budgeted movies, that is,movies with budget of 25 crore or more?

# %%
# Filter high-budget movies
high_budget_movies = df[df['Budget'] > 25]

# %%
high_budget_movies
# Out:
#      SlNo Release Date                    MovieName ReleaseTime    Genre
# 0       1    18-Apr-14                     2 States          LW  Romance  \
# 6       7    19-Sep-14                Daawat-E-Ishq           N   Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N   Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW   Comedy
# 10     11    28-Mar-14                  Dishkiyaoon           N  Action
# ..    ...          ...                          ...         ...      ...
# 138   139    23-Jan-15                         Baby           N   Action
# 141   142     6-Feb-15                    Shamitabh           N   Drama
# 142   143    13-Feb-15                          Roy          FS  Romance
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N   Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS   Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %%
# Plot the results
plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='Budget', data=df, palette='viridis')
plt.title('Number of High-Budget Movie Releases by Month')
plt.xlabel('Month')
plt.ylabel('Number of Releases')
plt.show()

# %% [markdown]
# Ans 6:-which are the top 10 movies with maximum return on investment(ROI)? Calculate return on investment(ROI) as(BoxOfficeCollection - Budget) / Budget

# %%
df["ROI"]= (df["BoxOfficeCollection"]-df["Budget"]) / df["Budget"]

# %%
df[["MovieName","ROI"]].sort_values("ROI",ascending=False)[0:10]
# Out:
#                      MovieName       ROI
# 64                  Aashiqui 2  8.166667
# 89                          PK  7.647059
# 132                Grand Masti  7.514286
# 135               The Lunchbox  7.500000
# 87                      Fukrey  6.240000
# 58                    Mary Kom  5.933333
# 128                     Shahid  5.666667
# 37   Humpty Sharma Ki Dulhania  5.500000
# 101         Bhaag Milkha Bhaag  4.466667
# 115            Chennai Express  4.266667

# %%
df[["MovieName","ROI"]].sort_values("ROI",ascending=True)[0:10]
# Out:
#                 MovieName       ROI
# 9               Gangoobai -0.995000
# 15                Bandook -0.977500
# 53               Sona Spa -0.976000
# 3        Rajdhani Express -0.950000
# 49   Kya Dilli Kya Lahore -0.928571
# 121               Satya 2 -0.926667
# 67           Purani Jeans -0.890000
# 103        Samrat and Co. -0.888889
# 30              Heartless -0.875000
# 102               Kaanchi -0.870968

# %% [markdown]
# Ans 8:- Draw a histogram and a distribution plot to find the distribution of movie budgets.Interpret the plot to conclude if the most movies are high or low budgeted movies.

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['Budget'], bins=30, kde=False, color='skyblue')
plt.title('Distribution of Movie Budgets')
plt.xlabel('Budget (Crore)')
plt.ylabel('Number of Movies')
plt.show()

# %%
# Plot distribution plot
plt.figure(figsize=(10, 6))
sns.histplot(df['Budget'], kde=True, color='skyblue')
plt.title('Distribution of Movie Budgets with KDE')
plt.xlabel('Budget (Crore)')
plt.ylabel('Density')
plt.show()
